# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Before model developement

we will do EDA:Exploratary data analysisi

Feature analysis

 - categorical,numerical bi variate,multivaraiate,outlier analysis
feature Engineering

- we will modify the data

- Models are developed by maths

- encoding means convert categorical data to numerical variables

- Scaling:All the feature are numerical columns makes under one scale value will reduce but not data

- Transformations: All the maths developed by making assumation but data follows normal distribution (Convert skew to Normal)
feature selection

# %%
file_path=r"C:\Users\user\Downloads\Visadataset (1).csv"
Visa_df=pd.read_csv(file_path)
Visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
Visa_df['case_status']
# Out:
# 0           Denied
# 1        Certified
# 2           Denied
# 3           Denied
# 4        Certified
#            ...
# 25475    Certified
# 25476    Certified
# 25477    Certified
# 25478    Certified
# 25479    Certified
# Name: case_status, Length: 25480, dtype: object

# %% [markdown]
# **Map Method**
#
#  - create a dictonary labless as keys number a values
#
#  -  in python index start with 0
#
#  -  case status has two labels we need two values 0 and 1
#
#  -  - Caertified become 0
#     - Denied become a 1

# %%
Visa_df['case_status'].nunique()
# Out:
# 2

# %%
Visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
d={'Certified':0,'Denied':1}
Visa_df['case_status']=Visa_df['case_status'].map(d)#case staus mapping with dict in same case status

# %%
Visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
d={}
d['Certified']=0
d['Denied']=1
d
# Out:
# {'Certified': 0, 'Denied': 1}

# %%
Visa_df=pd.read_csv(file_path)
d={}
labels=Visa_df['case_status'].unique()
for i in range(len(labels)):
    d[labels[i]]=i
print(d)
Visa_df['case_status']=Visa_df['case_status'].map(d)
# Out:
# {'Denied': 0, 'Certified': 1}

# %%
Visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
Visa_df=pd.read_csv(file_path)
labels=Visa_df['case_status'].unique()
d={labels[i]:i for i in range(len(labels))}
Visa_df['case_status']=Visa_df['case_status'].map(d)

# %%
Visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
types=Visa_df.dtypes
cat=[i for i,j in types.items() if j=='object']
cat
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position']

# %%
num=[i for i,j in types.items() if j!='object']
num
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage', 'case_status']

# %%
Visa_df=pd.read_csv(file_path)

# %%
Visa_df=pd.read_csv(file_path)
for i in cat:
    labels=Visa_df[i].unique()
    d={labels[i]:i for i in range(len(labels))}
    Visa_df[i]=Visa_df[i].map(d)

# %%
Visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          0                      0                   0
# 1            1          0                      1                   1
# 2            2          0                      2                   0
# 3            3          0                      2                   0
# 4            4          1                      1                   1
# ...        ...        ...                    ...                 ...
# 25475    25475          0                      2                   1
# 25476    25476          0                      0                   1
# 25477    25477          0                      1                   1
# 25478    25478          0                      1                   1
# 25479    25479          0                      2                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %% [markdown]
# **Label Encoding**
#
# - Sickit-learn(sklearn)
#
# - sklearn is heart of machine learning
#
# - mlLib is heart of Machine learning in pyspark
#
# - sklearn
#
#   - preprocess
#
#     - Label Encoder(Method)
#
# - fit : caluculate some thing like sum caterigoriacal and numerical
#
# - fit_transformd:we are modify the values because odf calculates one

# %%
Visa_df=pd.read_csv(file_path)

# %%
from sklearn.preprocessing import LabelEncoder # read the method
le=LabelEncoder()#sace the method #fitting and tranformation 
le.fit_transform(Visa_df['case_status'])#APPLY FIT TRANSFORM
# Out:
# array([1, 0, 1, ..., 0, 0, 0])

# %% [markdown]
# **One Hot encoder**

# %%
Case_status  Label_encoder
denier           1
certified         0
certified        0
Denied            1

case_status           cs denied                   cs Denied    --->curse of deversity
Denied                    1                            0
certififed               0                             1
certified                0                              1 
Denied                  1                                0
# Out:
#   Cell In[44], line 1
#     Case_status  Label_encoder
#                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# - OneHotEncoder creates new columns  that equal to number of unqiue labels
#
# - one Disturbution is data dimensiona will bw increased
#
# - More dimensions leads to more processing time leads to bigger infra memory
#
# - This is know as **curse of dimensionality**
#
#     - generally ml alogorithms excepts no correlation blw input columns
#
#     - whwn one column value available and at a same time another column value is not avalible means both are independent each other

# %%
Visa_df=pd.read_csv(file_path)

# %%
pd.get_dummies(Visa_df,columns=cat[1:],dtype=int)
# Out:
#          case_id  no_of_employees  yr_of_estab  prevailing_wage case_status  \
# 0         EZYV01            14513         2007         592.2029      Denied
# 1         EZYV02             2412         2002       83425.6500   Certified
# 2         EZYV03            44444         2008      122996.8600      Denied
# 3         EZYV04               98         1897       83434.0300      Denied
# 4         EZYV05             1082         2005      149907.3900   Certified
# ...          ...              ...          ...              ...         ...
# 25475  EZYV25476             2601         2008       77092.5700   Certified
# 25476  EZYV25477             3274         2006      279174.7900   Certified
# 25477  EZYV25478             1121         1910      146298.8500   Certified
# 25478  EZYV25479             1918         1887       86154.7700   Certified
# 25479  EZYV25480             3195         1960       70876.9100   Certified
#
# ...

# %%
Visa_df['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %% [markdown]
# - if data is in ordinal go with labelEncoder
#
# - if data is nominal go with OneHotEncoder
#
# if labels are more go with LabelEncoder
#
# if Lables are less go with OneHotEndoer
